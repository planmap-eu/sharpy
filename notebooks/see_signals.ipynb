# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
lbl_file = "/data/SciBigData/radargrams/nicole_thesis/s_00325703_tiff.lbl"

# %%
import gdal

# open dataset
ds = gdal.Open(lbl_file)

# %%
data = ds.ReadAsArray()
data = data.astype(np.float)

# %%
imshow(data)

# %%
plot(data[:,2000][2000:3000])

# %%
from skimage.restoration import (denoise_wavelet, estimate_sigma)

# %%
sigma_est = estimate_sigma(data, multichannel=True, average_sigmas=True)

# %%
sigma_est
# Out:
# 4.048617375086745

# %%
im_bayes = denoise_wavelet(data, sigma=sigma_est)


im_visushrink = denoise_wavelet(data, multichannel=False, convert2ycbcr=True,
                                method='VisuShrink', mode='soft',
                                sigma=sigma_est)

# %%
imshow(im_bayes)

# %%
imshow(im_visushrink)

# %%
plot(im_bayes[:,2000][2000:3000])
